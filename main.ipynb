# %%
from langdetect import detect
from googletrans import Translator
import spacy

nlp_en = spacy.load("en_core_web_sm")
nlp_es = spacy.load("es_core_news_sm")
translator = Translator()

INTENT_KEYWORDS = {
    "food": ["food", "hunger", "meal", "pantry", "eat"],
    "housing": ["housing", "rent", "shelter", "home", "eviction"],
    "job": ["job", "work", "employment", "hire", "career"]
}

def detect_language(text):
    try:
        lang = detect(text)
        return lang
    except:
        return "en"

def translate_to_english(text, lang):
    if lang != "en":
        try:
            translated = translator.translate(text, src=lang, dest="en")
            return translated.text
        except:
            return text
    return text

def extract_intent(text):
    for intent, keywords in INTENT_KEYWORDS.items():
        for kw in keywords:
            if kw in text.lower():
                return intent
    return "unknown"

def extract_entities(text, lang):
    doc = nlp_en(text) if lang == "en" else nlp_es(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

def process_message(text):
    lang = detect_language(text)
    translated = translate_to_english(text, lang)
    intent = extract_intent(translated)
    entities = extract_entities(translated, lang)
    
    return {
        "original": text,
        "language": lang,
        "translated": translated,
        "intent": intent,
        "entities": entities
    }

# %%
#testing

msg = "¿Dónde puedo encontrar un banco de comida cerca de mí?"
result = process_message(msg)

print(result)
# Out:
# {'original': '¿Dónde puedo encontrar un banco de comida cerca de mí?', 'language': 'es', 'translated': 'Where can I find a food bank near me?', 'intent': 'food', 'entities': [('bank near me?', 'ORG')]}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def get_category_links(base_url="https://volunteerinfo.org"):
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, "html.parser")

    category_li = soup.find("li", id="categories-3")
    category_links = []
    if category_li:
        for a_tag in category_li.find_all("a"):
            name = a_tag.text.strip()
            href = a_tag.get("href")
            if href:
                category_links.append((name, href))
    return category_links

def scrape_category(category_name, base_url):
    nonprofits = {}

    page = 1
    while True:
        if page == 1:
            url = base_url
        else:
            url = f"{base_url}page/{page}/"

        response = requests.get(url)
        if response.status_code != 200:
            print(f"Reached end of pages for {category_name}")
            break

        soup = BeautifulSoup(response.content, "html.parser")
        titles = soup.find_all("h2", class_="entry-title")
        summaries = soup.find_all("div", class_="entry-summary")

        if not titles:
            break

        for title_tag, summary_tag in zip(titles, summaries):
            a_tag = title_tag.find("a")
            name = a_tag.text.strip()
            link = a_tag['href']
            p_tag = summary_tag.find("p")
            summary = p_tag.text.strip() if p_tag else ""

            if link in nonprofits:
                if category_name not in nonprofits[link]["Category"]:
                    nonprofits[link]["Category"].append(category_name)
            else:
                nonprofits[link] = {
                    "Name": name,
                    "URL": link,
                    "Summary": summary,
                    "Category": [category_name]
                }

        page += 1
        time.sleep(0.2)

    return nonprofits

# Run Full Scrape
all_nonprofits = {}

categories = get_category_links()
for cat_name, cat_url in categories:
    scraped = scrape_category(cat_name, cat_url)
    for link, info in scraped.items():
        if link in all_nonprofits:
            existing = all_nonprofits[link]
            for cat in info["Category"]:
                if cat not in existing["Category"]:
                    existing["Category"].append(cat)
        else:
            all_nonprofits[link] = info

# Convert to DataFrame
data = []
for org in all_nonprofits.values():
    data.append({
        "Name": org["Name"],
        "URL": org["URL"],
        "Summary": org["Summary"],
        "Category": ", ".join(org["Category"])
    })

df = pd.DataFrame(data)
df.to_csv("all_nonprofits_volunteerinfo.csv", index=False)
print(df.head())
# Out:
# Reached end of pages for Abuse and Neglect
# Reached end of pages for Adoption and Foster Care
# Reached end of pages for Advocacy and Human Rights
# Reached end of pages for Agriculture
# Reached end of pages for Alameda
# Reached end of pages for Albany
# Reached end of pages for Animals
# Reached end of pages for Arts and Culture
# Reached end of pages for Assisted Living
# Reached end of pages for Bakersfield
# Reached end of pages for Berkeley
# Reached end of pages for Board Development
# Reached end of pages for Burlingame
# Reached end of pages for Castro Valley
# Reached end of pages for Central Valley
# Reached end of pages for Children and Families
# Reached end of pages for Civic Engagement
# Reached end of pages for Communications Access
# Reached end of pages for Community Development
# Reached end of pages for Computers and Technology
# Reached end of pages for Concord
# Reached end of pages for Conflict Resolution
# Reached end of pages for Consumer Protection
# Reached end of pages for Contra Costa County
# Reached end of pages for Counseling, Therapy, and Emotional Support
# Reached end of pages for Crime and Safety
# Reached end of pages for Crisis Support
# Reached end of pages for Cupertino
# Reached end of pages for Daly City
# Reached end of pages for Danville
# Reached end of pages for Disability and Special Needs
# Reached end of pages for Disaster Relief
# Reached end of pages for Domestic Violence
# Reached end of pages for East Bay
# Reached end of pages for Economic Development
# Reached end of pages for Education and Literacy
# Reached end of pages for El Cerrito
# Reached end of pages for El Sobrante
# Reached end of pages for Emergency and Safety
# Reached end of pages for Emeryville
# Reached end of pages for Employment
# Reached end of pages for Energy Conservation
# Reached end of pages for Environment
# Reached end of pages for Fairfield
# Reached end of pages for Faith-Based
# Reached end of pages for Family Planning
# Reached end of pages for Food and Clothing
# Reached end of pages for Foster City
# Reached end of pages for Fremont
# Reached end of pages for Fresno
# Reached end of pages for Funding and Financial Assistance
# Reached end of pages for Fundraising
# Reached end of pages for Government Reform
# Reached end of pages for Grief and Loss
# Reached end of pages for Half Moon Bay
# Reached end of pages for Hayward
# Reached end of pages for Health and Medicine
# Reached end of pages for Hercules
# Reached end of pages for Housing and Homelessness
# Reached end of pages for Human Rights and Civil Liberties
# Reached end of pages for Human Services
# Reached end of pages for Hunger
# Reached end of pages for Immigrants and Refugees
# Reached end of pages for Independent Living
# Reached end of pages for International
# Reached end of pages for Job and Workplace
# Reached end of pages for Justice and Legal
# Reached end of pages for Lafayette
# Reached end of pages for LGBT
# Reached end of pages for Library and Resource Centers
# Reached end of pages for Los Altos
# Reached end of pages for Los Gatos
# Reached end of pages for Marin County
# Reached end of pages for Media and Broadcasting
# Reached end of pages for Menlo Park
# Reached end of pages for Mental Health
# Reached end of pages for Mentorship and Tutoring
# Reached end of pages for Milpitas
# Reached end of pages for Miscellaneous
# Reached end of pages for Modesto
# Reached end of pages for Monterey Bay Area
# Reached end of pages for Mountain View
# Reached end of pages for Multi-Service Agency
# Reached end of pages for Museums and History
# Reached end of pages for Napa County
# Reached end of pages for Network of Nonprofits
# Reached end of pages for Newark
# Reached end of pages for North Bay
# Reached end of pages for Nutrition and Exercise
# Reached end of pages for Oakland
# Reached end of pages for Palo Alto
# Reached end of pages for Peer Counseling
# Reached end of pages for Peninsula
# Reached end of pages for Performing and Fine Arts
# Reached end of pages for Personal Finance
# Reached end of pages for Philanthropy
# Reached end of pages for Piedmont
# Reached end of pages for Pinole
# Reached end of pages for Pleasanton
# Reached end of pages for Policy Advocacy
# Reached end of pages for Politics
# Reached end of pages for Poverty and Hunger
# Reached end of pages for Prison Reform
# Reached end of pages for Professional Association
# Reached end of pages for Race and Ethnicity
# Reached end of pages for Redwood City
# Reached end of pages for Religion and Spirituality
# Reached end of pages for Research and Science
# Reached end of pages for Richmond
# Reached end of pages for Rural
# Reached end of pages for Sacramento
# Reached end of pages for San Bruno
# Reached end of pages for San Francisco
# Reached end of pages for San Jose
# Reached end of pages for San Leandro
# Reached end of pages for San Lorenzo
# Reached end of pages for San Mateo County
# Reached end of pages for San Pablo
# Reached end of pages for San Rafael
# Reached end of pages for Santa Clara
# Reached end of pages for Santa Cruz
# Reached end of pages for Santa Rosa
# Reached end of pages for Saratoga
# Reached end of pages for Seniors
# Reached end of pages for Silicon Valley
# Reached end of pages for Social Enterprise
# Reached end of pages for Sonoma County
# Reached end of pages for South Bay
# Reached end of pages for Sports and Recreation
# Reached end of pages for Stockton
# Reached end of pages for Substance Abuse
# Reached end of pages for Sunnyvale
# Reached end of pages for Sustainability
# Reached end of pages for Terminal Illness
# Reached end of pages for Travel and Transportation
# Reached end of pages for Union City
# Reached end of pages for Urban
# Reached end of pages for Veterans and Military Families
# Reached end of pages for Victim Support
# Reached end of pages for Walnut Creek
# Reached end of pages for Women
# Reached end of pages for Woodside
# Reached end of pages for Youth
#                                                 Name  \
# 0  Sexual Assault & Domestic Violence Response an...
# 1                    There With Care of the Bay Area
# 2  Little Brothers -Friends of the Elderly San Fr...
# 3                                    The Living Room
# 4                       Care Through Touch Institute
#
#                                                  URL  \
# 0  https://volunteerinfo.org/sexual-assault-domes...
# 1  https://volunteerinfo.org/there-with-care-of-t...
# 2  https://volunteerinfo.org/little-brothers-frie...
# 3         https://volunteerinfo.org/the-living-room/
# 4  https://volunteerinfo.org/care-through-touch-i...
#
#                                              Summary  \
# 0  The Sexual Assault & Domestic Violence Respons...
# 1  Description of Organization and/or Volunteer O...
# 2  Little Brothers – Friends of the Elderly (LBFE...
# 3  We offer food services, transitional housing, ...
# 4  Description of Organization and/or Volunteer O...
#
#                                             Category
# 0  Abuse and Neglect, Advocacy and Human Rights, ...
# 1  Abuse and Neglect, Advocacy and Human Rights, ...
# 2  Abuse and Neglect, Civic Engagement, Housing a...
# 3  Abuse and Neglect, Children and Families, Civi...
# 4  Abuse and Neglect, Community Development, Coun...

# %%
df.head(10)
# Out:
#                                                 Name  \
# 0  Sexual Assault & Domestic Violence Response an...
# 1                    There With Care of the Bay Area
# 2  Little Brothers -Friends of the Elderly San Fr...
# 3                                    The Living Room
# 4                       Care Through Touch Institute
# 5                            Project Delta View Cats
# 6                                       Shelter Tech
# 7                                     Circle of Care
# 8                                       Safe & Sound
# 9                            Bay Area Crisis Nursery
#
#                                                  URL  \
# 0  https://volunteerinfo.org/sexual-assault-domes...
# 1  https://volunteerinfo.org/there-with-care-of-t...
# 2  https://volunteerinfo.org/little-brothers-frie...
# 3         https://volunteerinfo.org/the-living-room/
# 4  https://volunteerinfo.org/care-through-touch-i...
# 5  https://volunteerinfo.org/project-delta-view-c...
# 6            https://volunteerinfo.org/shelter-tech/
# 7          https://volunteerinfo.org/circle-of-care/
# 8              https://volunteerinfo.org/safe-sound/
# 9  https://volunteerinfo.org/bay-area-crisis-nurs...
#
#                                              Summary  \
# 0  The Sexual Assault & Domestic Violence Respons...
# 1  Description of Organization and/or Volunteer O...
# 2  Little Brothers – Friends of the Elderly (LBFE...
# 3  We offer food services, transitional housing, ...
# 4  Description of Organization and/or Volunteer O...
# 5  Project Delta View Cats is a 100 % volunteer-l...
# 6  Shelter Tech aims to build the most reliable, ...
# 7  Playful and compassionate volunteers needed to...
# 8  OUR MISSION To prevent child abuse and reduce ...
# 9  Bay Area Crisis Nursery is a gateway organizat...
#
#                                             Category
# 0  Abuse and Neglect, Advocacy and Human Rights, ...
# 1  Abuse and Neglect, Advocacy and Human Rights, ...
# 2  Abuse and Neglect, Civic Engagement, Housing a...
# 3  Abuse and Neglect, Children and Families, Civi...
# 4  Abuse and Neglect, Community Development, Coun...
# 5  Abuse and Neglect, Animals, Central Valley, Ea...
# 6  Abuse and Neglect, Advocacy and Human Rights, ...
# 7  Abuse and Neglect, Children and Families, Coun...
# 8  Abuse and Neglect, Adoption and Foster Care, A...
# 9  Abuse and Neglect, Children and Families, Conc...
